# %%
import pandas as pd
from scipy import stats

# %%
aqi = pd.read_csv('C:\\Users\\hp\\Desktop\\PYTHON\\Stat\\Day 1\\c4_epa_air_quality.csv')
aqi
# Out:
#      Unnamed: 0  date_local            state_name           county_name  \
# 0             0  2018-01-01               Arizona              Maricopa
# 1             1  2018-01-01                  Ohio               Belmont
# 2             2  2018-01-01               Wyoming                 Teton
# 3             3  2018-01-01          Pennsylvania          Philadelphia
# 4             4  2018-01-01                  Iowa                  Polk
# ..          ...         ...                   ...                   ...
# 255         255  2018-01-01  District Of Columbia  District of Columbia
# 256         256  2018-01-01             Wisconsin                 Dodge
# 257         257  2018-01-01              Kentucky             Jefferson
# 258         258  2018-01-01              Nebraska               Douglas
# 259         259  2018-01-01        North Carolina                  Wake
#
#          city_name                                    local_site_name  \
# ...

# %%
aqi.describe()
# Out:
#        Unnamed: 0  arithmetic_mean         aqi
# count  260.000000       260.000000  260.000000
# mean   129.500000         0.403169    6.757692
# std     75.199734         0.317902    7.061707
# min      0.000000         0.000000    0.000000
# 25%     64.750000         0.200000    2.000000
# 50%    129.500000         0.276315    5.000000
# 75%    194.250000         0.516009    9.000000
# max    259.000000         1.921053   50.000000

# %%
aqi.value_counts()
# Out:
# Unnamed: 0  date_local  state_name      county_name  city_name                                  local_site_name                 parameter_name   units_of_measure   arithmetic_mean  aqi
# 0           2018-01-01  Arizona         Maricopa     Buckeye                                    BUCKEYE                         Carbon monoxide  Parts per million  0.473684         7      1
# 131         2018-01-01  Arizona         Maricopa     Phoenix                                    CENTRAL PHOENIX                 Carbon monoxide  Parts per million  1.110526         27     1
# 165         2018-01-01  Utah            Weber        Ogden                                      Ogden                           Carbon monoxide  Parts per million  0.326316         7      1
# 166         2018-01-01  New Jersey      Hudson       Jersey City                                Jersey City                     Carbon monoxide  Parts per million  0.133333         3      1
# ...

# %%
aqi.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 aqi.shape()
#
# TypeError: 'tuple' object is not callable

# %%
aqi.head()

# %% [markdown]
# STATISTICAL TEST

# %% [markdown]
# HYPOTHESIS 1
# ROA is considering a metropolitan-focused approach. Within
# California, they want to know if the mean AQI in Ohio County is statistically different from the rest of California.

# %%
aqi_california = aqi[aqi['state_name'] == 'California']
aqi_california.head(5)
# Out:
#     Unnamed: 0  date_local  state_name     county_name      city_name  \
# 16          16  2018-01-01  California  San Bernardino        Ontario
# 18          18  2018-01-01  California      Sacramento   Arden-Arcade
# 26          26  2018-01-01  California          Orange       La Habra
# 27          27  2018-01-01  California         Alameda  Not in a city
# 33          33  2018-01-01  California     Los Angeles      Lancaster
#
#                  local_site_name   parameter_name   units_of_measure  \
# 16  Ontario Near Road (Etiwanda)  Carbon monoxide  Parts per million
# 18     Sacramento-Del Paso Manor  Carbon monoxide  Parts per million
# 26                      La Habra  Carbon monoxide  Parts per million
# 27        Berkeley- Aquatic Park  Carbon monoxide  Parts per million
# 33     Lancaster-Division Street  Carbon monoxide  Parts per million
#
#     arithmetic_mean  aqi
# 16         0.747368   11
# 18         0.752632   16
# 26         0.673684   13
# ...

# %%
aqi_new_york = aqi[aqi['county_name'] == 'New York']
aqi_new_york
# Out:
#      Unnamed: 0  date_local state_name county_name city_name local_site_name  \
# 167         167  2018-01-01   New York    New York  New York            CCNY
#
#       parameter_name   units_of_measure  arithmetic_mean  aqi
# 167  Carbon monoxide  Parts per million              0.2    2

# %%
sample_aqi_california = aqi_california.sample( n=20, replace=True, random_state=100)
sample_aqi_california.head(10)
# Out:
#      Unnamed: 0  date_local  state_name     county_name       city_name  \
# 43           43  2018-01-01  California    Contra Costa         Concord
# 110         110  2018-01-01  California     Los Angeles     Los Angeles
# 198         198  2018-01-01  California       Riverside    Palm Springs
# 46           46  2018-01-01  California       Riverside       Mira Loma
# 206         206  2018-01-01  California  San Bernardino  San Bernardino
# 211         211  2018-01-01  California          Fresno   Not in a city
# 63           63  2018-01-01  California      Sacramento   Not in a city
# 148         148  2018-01-01  California    Contra Costa       San Pablo
# 110         110  2018-01-01  California     Los Angeles     Los Angeles
# 75           75  2018-01-01  California     San Joaquin        Stockton
#
#                    local_site_name   parameter_name   units_of_measure  \
# 43                         Concord  Carbon monoxide  Parts per million
# ...

# %%
sample_aqi_new_york = aqi_new_york.sample( n=20, replace=True, random_state=100)
sample_aqi_new_york.head(5)
# Out:
#      Unnamed: 0  date_local state_name county_name city_name local_site_name  \
# 167         167  2018-01-01   New York    New York  New York            CCNY
# 167         167  2018-01-01   New York    New York  New York            CCNY
# 167         167  2018-01-01   New York    New York  New York            CCNY
# 167         167  2018-01-01   New York    New York  New York            CCNY
# 167         167  2018-01-01   New York    New York  New York            CCNY
#
#       parameter_name   units_of_measure  arithmetic_mean  aqi
# 167  Carbon monoxide  Parts per million              0.2    2
# 167  Carbon monoxide  Parts per million              0.2    2
# 167  Carbon monoxide  Parts per million              0.2    2
# 167  Carbon monoxide  Parts per million              0.2    2
# 167  Carbon monoxide  Parts per million              0.2    2

# %%
stats.ttest_ind(a= sample_aqi_california['aqi'], b= sample_aqi_new_york['aqi'], equal_var=False)   #equal_var set to false cuz we dont want to assume two sample having same variance
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# TtestResult(statistic=6.860156974991873, pvalue=1.5174361140551958e-06, df=19.0)

# %%
p_value = 1.5174361140551958e-06
alpha = 0.5
if p_value < alpha:
    print("The mean AQI in California is statistically different from the rest of New York.")
else:
    print("There is not enough evidence to say the mean AQI in California is different from the rest of New York.")

#p value 1.517..-06 which is less than 0.5 so we reject null hypothesis
# Out:
# The mean AQI in California is statistically different from the rest of New York.

# %% [markdown]
# Hypothesis 2: With limited resources, ROA has to choose between New York
# and Ohio for their next regional office. Does New York have a lower AQI than
# Ohio?

# %%
aqi_arizona = aqi[aqi['state_name'] == 'Arizona']
aqi_arizona.head(5)
# Out:
#     Unnamed: 0  date_local state_name county_name city_name  \
# 0            0  2018-01-01    Arizona    Maricopa   Buckeye
# 13          13  2018-01-01    Arizona    Maricopa      Mesa
# 19          19  2018-01-01    Arizona        Pima    Tucson
# 67          67  2018-01-01    Arizona    Maricopa  Chandler
# 69          69  2018-01-01    Arizona    Maricopa   Phoenix
#
#           local_site_name   parameter_name   units_of_measure  \
# 0                 BUCKEYE  Carbon monoxide  Parts per million
# 13                   MESA  Carbon monoxide  Parts per million
# 19  CHILDREN'S PARK NCore  Carbon monoxide  Parts per million
# 67          WEST CHANDLER  Carbon monoxide  Parts per million
# 69          JLG SUPERSITE  Carbon monoxide  Parts per million
#
#     arithmetic_mean  aqi
# 0          0.473684    7
# 13         0.505263   10
# 19         0.331579    7
# 67         0.800000   19
# 69         0.978947   20

# %%
aqi_ohio = aqi[aqi['state_name'] == 'Ohio']
aqi_ohio.head(5)
# Out:
#     Unnamed: 0  date_local state_name county_name   city_name local_site_name  \
# 1            1  2018-01-01       Ohio     Belmont   Shadyside       Shadyside
# 12          12  2018-01-01       Ohio    Hamilton  Cincinnati      Taft NCore
# 22          22  2018-01-01       Ohio       Stark      Canton          Canton
# 51          51  2018-01-01       Ohio      Summit       Akron    NIHF STEM MS
# 59          59  2018-01-01       Ohio    Cuyahoga   Cleveland  GT Craig NCore
#
#      parameter_name   units_of_measure  arithmetic_mean  aqi
# 1   Carbon monoxide  Parts per million         0.263158    5
# 12  Carbon monoxide  Parts per million         0.252632    3
# 22  Carbon monoxide  Parts per million         0.394737    6
# 51  Carbon monoxide  Parts per million         0.083333    3
# 59  Carbon monoxide  Parts per million         0.250000    3

# %%
sample_aqi_arizona = aqi_arizona.sample(n=20, replace=True, random_state = 1300)
sample_aqi_arizona.head()
# Out:
#      Unnamed: 0  date_local state_name county_name city_name  \
# 210         210  2018-01-01    Arizona        Pima    Tucson
# 254         254  2018-01-01    Arizona        Pima    Tucson
# 13           13  2018-01-01    Arizona    Maricopa      Mesa
# 13           13  2018-01-01    Arizona    Maricopa      Mesa
# 19           19  2018-01-01    Arizona        Pima    Tucson
#
#            local_site_name   parameter_name   units_of_measure  \
# 210             GOLF LINKS  Carbon monoxide  Parts per million
# 254         CHERRY & GLENN  Carbon monoxide  Parts per million
# 13                    MESA  Carbon monoxide  Parts per million
# 13                    MESA  Carbon monoxide  Parts per million
# 19   CHILDREN'S PARK NCore  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 210         0.268421    5
# 254         0.563158   14
# 13          0.505263   10
# 13          0.505263   10
# 19          0.331579    7

# %%
sample_aqi_ohio = aqi_ohio.sample(n=20, replace=True, random_state = 1000)
sample_aqi_ohio.head()
# Out:
#      Unnamed: 0  date_local state_name county_name   city_name  \
# 51           51  2018-01-01       Ohio      Summit       Akron
# 191         191  2018-01-01       Ohio    Franklin    Columbus
# 191         191  2018-01-01       Ohio    Franklin    Columbus
# 1             1  2018-01-01       Ohio     Belmont   Shadyside
# 252         252  2018-01-01       Ohio    Hamilton  Cincinnati
#
#           local_site_name   parameter_name   units_of_measure  \
# 51           NIHF STEM MS  Carbon monoxide  Parts per million
# 191   Smoky Row Near Road  Carbon monoxide  Parts per million
# 191   Smoky Row Near Road  Carbon monoxide  Parts per million
# 1               Shadyside  Carbon monoxide  Parts per million
# 252  Cincinnati Near Road  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 51          0.083333    3
# 191         0.115789    2
# 191         0.115789    2
# 1           0.263158    5
# 252         0.226316    3

# %%
sample_aqi_arizona['aqi'].mean()
# Out:
# 12.9

# %%
sample_aqi_ohio['aqi'].mean()
# Out:
# 3.15

# %%
#Ohio has lower AQI than Arizona.

# %%
stats.ttest_ind(a= sample_aqi_arizona['aqi'], b=sample_aqi_ohio['aqi'])
# Out:
# TtestResult(statistic=4.011909443323024, pvalue=0.0002725815994296957, df=38.0)

# %%
#t value is statistic=4.011909443323024
#p value 0.0002725815994296957 which is less than 0.5 is null hypothesis

# %% [markdown]
# Hypothesis 3: A new policy will affect those states with a mean AQI of 10 or
# greater. Will Michigan be affected by this new policy?

# %%
aqi_michigan = aqi[aqi['state_name'] == 'Michigan']
aqi_michigan.head()
# Out:
#      Unnamed: 0  date_local state_name county_name   city_name  \
# 65           65  2018-01-01   Michigan       Wayne     Livonia
# 122         122  2018-01-01   Michigan       Wayne     Detroit
# 123         123  2018-01-01   Michigan       Wayne     Detroit
# 129         129  2018-01-01   Michigan       Wayne     Detroit
# 192         192  2018-01-01   Michigan       Wayne  Allen Park
#
#               local_site_name   parameter_name   units_of_measure  \
# 65                 LIVONIA-NR  Carbon monoxide  Parts per million
# 122               West corner  Carbon monoxide  Parts per million
# 123  MARK TWAIN MIDDLE SCHOOL  Carbon monoxide  Parts per million
# 129                  ELIZA-NR  Carbon monoxide  Parts per million
# 192                Allen Park  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 65          0.338889    5
# 122         0.394737    8
# 123         0.515789    9
# 129         0.616667   11
# 192         0.811111   13

# %%
sample_aqi_michigan = aqi_michigan.sample(n=20, replace= True, random_state= 1200)
sample_aqi_michigan.head()
# Out:
#      Unnamed: 0  date_local state_name county_name      city_name  \
# 129         129  2018-01-01   Michigan       Wayne        Detroit
# 242         242  2018-01-01   Michigan       Wayne        Detroit
# 65           65  2018-01-01   Michigan       Wayne        Livonia
# 123         123  2018-01-01   Michigan       Wayne        Detroit
# 207         207  2018-01-01   Michigan       Wayne  Not in a city
#
#               local_site_name   parameter_name   units_of_measure  \
# 129                  ELIZA-NR  Carbon monoxide  Parts per million
# 242        (Northeast corner)  Carbon monoxide  Parts per million
# 65                 LIVONIA-NR  Carbon monoxide  Parts per million
# 123  MARK TWAIN MIDDLE SCHOOL  Carbon monoxide  Parts per million
# 207            Eliza Downwind  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 129         0.616667   11
# 242         0.378947    7
# 65          0.338889    5
# 123         0.515789    9
# 207         0.516667   10

# %%
sample_aqi_michigan['aqi'].mean()
# Out:
# 8.6

# %%
stats.ttest_ind(sample_aqi_michigan['aqi'],8.6,alternative='greater')
# Out:
# TtestResult(statistic=0.0, pvalue=0.5, df=19.0)

# %% [markdown]
# p_value is equal to 0.5 which is alternative hypothesis . This suggests there is not enough evidence to conclude that the mean AQI in Michigan is greater than 10. Thus, based on this test, Michigan would not be affected by the new policy
